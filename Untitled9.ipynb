# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitagarwal6367/Python/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.tail()  ### bottom 5 dta
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.head()  ### top 5 data
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.describe()  ### statically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()  ### Data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:4, :3]   ## iloc[row_range, column range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3, ['cgpa', 'placed']]  ### Loc[row range, column range]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty    ## it return true if
b
# Out:
# False

# %%
df.isnull().sum()    ### for checking missing value
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()    ### for remove missing value
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i = df.ndim  ## number of axis( it is 2)
i
# Out:
# 2

# %%
t = df.shape
t   ###shape = n(rows), n(column)
# Out:
# (100, 3)

# %%
d= df.size
d     ###  size = n(rows)* n(column)
# Out:
# 300

# %%
d = df.values
d
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
t
df['cgpa'] = df['cgpa'].astype(int)

# %%
t
df['cgpa'] = df['cgpa'].astype(int)

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
s = df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            9.00
# resume_score    9.06
# placed          1.00
# dtype: float64

# %%
q = df.min()
q
# Out:
# cgpa            5.00
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
r = df['cgpa'].mean()
r
# Out:
# np.float64(6.47)

# %%
s = df['cgpa'].median()
s
# Out:
# 6.0

# %%
s = df.sum()
s
# Out:
# cgpa            647.00
# resume_score    693.05
# placed           50.00
# dtype: float64

# %%
g = df.filter(items = ['cgpa', 'placed'])
g
df[['cgpa', 'placed']]     ### second option of filtering
# Out:
#     cgpa  placed
# 0      8       1
# 1      6       0
# 2      8       1
# 3      6       1
# 4      7       1
# ..   ...     ...
# 95     6       0
# 96     8       1
# 97     6       0
# 98     8       1
# 99     6       0
#
# [100 rows x 2 columns]

# %%
p = df.rename(columns = {'cgpa':'update_cgpa', 'resume_score':'semester_marks'})
p
# Out:
#     update_cgpa  semester_marks  placed
# 0             8            6.52       1
# 1             6            5.17       0
# 2             8            8.86       1
# 3             6            7.27       1
# 4             7            7.30       1
# ..          ...             ...     ...
# 95            6            6.38       0
# 96            8            7.76       1
# 97            6            7.78       0
# 98            8            5.63       1
# 99            6            6.61       0
#
# [100 rows x 3 columns]

# %% [markdown]
# **import tips dataset**

# %%
df = pd.read_csv("/content/tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Methods of Pandas

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
top_left_corner_df = df.iloc[:4, :3]   ## iloc[row_range, column range]
top_left_corner_df
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male

# %%
df.loc[1:3, ['sex', 'smoker']]  ### Loc[row range, column range]
# Out:
#     sex smoker
# 1  Male     No
# 2  Male     No
# 3  Male     No

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=244, step=1),
#  Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.dropna()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
i = df.ndim
i
# Out:
# 2

# %%
t = df.shape
t
# Out:
# (244, 7)

# %%
t = df.size
t
# Out:
# 1708

# %%
df= df.copy()

# %%
p = df.sort_values(by='sex')
p
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 139       13.16  2.75  Female     No  Thur   Lunch     2
# 137       14.15  2.00  Female     No  Thur   Lunch     2
# 136       10.33  2.00  Female     No  Thur   Lunch     2
# 135        8.51  1.25  Female     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 42        13.94  3.06    Male     No   Sun  Dinner     2
# 41        17.46  2.54    Male     No   Sun  Dinner     2
# 39        31.27  5.00    Male     No   Sat  Dinner     3
# 156       48.17  5.00    Male     No   Sun  Dinner     6
#
# [244 rows x 7 columns]

# %%
df['size']=df['size'].astype(int)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size']= df['size'].add(4)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     6
# 1         10.34  1.66    Male     No   Sun  Dinner     7
# 2         21.01  3.50    Male     No   Sun  Dinner     7
# 3         23.68  3.31    Male     No   Sun  Dinner     6
# 4         24.59  3.61  Female     No   Sun  Dinner     8
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     7
# 240       27.18  2.00  Female    Yes   Sat  Dinner     6
# 241       22.67  2.00    Male    Yes   Sat  Dinner     6
# 242       17.82  1.75    Male     No   Sat  Dinner     6
# 243       18.78  3.00  Female     No  Thur  Dinner     6
#
# [244 rows x 7 columns]

# %%
p = df.max()
p
# Out:
# total_bill    50.81
# tip            10.0
# sex            Male
# smoker          Yes
# day            Thur
# time          Lunch
# size             10
# dtype: object

# %%
r = df['size'].mean()
r
# Out:
# np.float64(6.569672131147541)

# %%
s=df['size'].median()
s
# Out:
# 6.0

# %% [markdown]
# Feature Engineering

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
x = df.drop(columns = ['placed'])
y
# Out:
#     cgpa  resume_score
# 0   8.14          6.52
# 1   6.17          5.17
# 2   8.27          8.86
# 3   6.88          7.27
# 4   7.52          7.30
# ..   ...           ...
# 95  6.33          6.38
# 96  8.23          7.76
# 97  6.65          7.78
# 98  8.14          5.63
# 99  6.09          6.61
#
# [100 rows x 2 columns]

# %%
## pip install scikitlearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

# %%
print("total df:", df.shape)
print("Input data(x):", x.shape)
print("Input data(x_train):", x_train.shape)
print("Input data(x_test):", x_test.shape)
print("-----------------------")
print("--------------------------")
print("Output data(y):", y.shape)
print("Output data(y_train:", y_train.shape)
print("output data(y_text)", y_test.shape)
# Out:
# total df: (100, 3)
# Input data(x): (100, 2)
# Input data(x_train): (80, 2)
# Input data(x_test): (20, 2)
# -----------------------
# --------------------------
# Output data(y): (100, 2)
# Output data(y_train: (80, 2)
# output data(y_text) (20, 2)

# %%
np.round(x_train.describe(), 2)
# Out:
#         cgpa  resume_score
# count  80.00         80.00
# mean    6.95          7.00
# std     1.13          1.01
# min     5.27          4.95
# 25%     6.00          6.28
# 50%     6.62          7.15
# 75%     8.06          7.69
# max     9.31          9.06

# %%
# our data mean value and standard deviation value are different so we have to
# use standard deviation to convert our data into normalization(mean=0, std=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()

# %%
x_train_sc = st.fit_transform(x_train)  ## fit means learn the feature and transform means apply  on that data

# %%
x_train_new = pd.DataFrame(x_train_sc, columns = x_train.columns)

# %%
np.round(x_train_new.describe(), 2)
# Out:
#         cgpa  resume_score
# count  80.00         80.00
# mean   -0.00         -0.00
# std     1.01          1.01
# min    -1.50         -2.04
# 25%    -0.85         -0.72
# 50%    -0.29          0.15
# 75%     0.99          0.69
# max     2.11          2.05

# %% [markdown]
# **2.  Normalization**

# %% [markdown]
# it will convert our minimum value of data = 0 and maximum value =1

# %%
df = pd.read_csv("/content/placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head(3)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1

# %%
np.round(x_train.describe(), 2)
# Out:
#         cgpa  resume_score
# count  80.00         80.00
# mean    6.95          7.00
# std     1.13          1.01
# min     5.27          4.95
# 25%     6.00          6.28
# 50%     6.62          7.15
# 75%     8.06          7.69
# max     9.31          9.06

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn = MinMaxScaler()

# %%
x_train_mn = mn.fit_transform(x_train)

# %%
x_train_new = pd.DataFrame(x_train_mn, columns = x_train.columns)

# %%
np.round(x_train_new.describe(), 2)
# Out:
#         cgpa  resume_score
# count  80.00         80.00
# mean    0.42          0.50
# std     0.28          0.25
# min     0.00          0.00
# 25%     0.18          0.32
# 50%     0.33          0.54
# 75%     0.69          0.67
# max     1.00          1.00

# %%
# models --->
# 1. Supervised ML Models ---> when we have labelled data
# 2. UnSupervised ML Models ---> when we have unlabelled data

# we have 2 type of data
# 1. Descrete or categorical ---> we cannot divide in further steps. i.e placed(yes,  no)
# convid(positive, negative), total_number_of_students_in_a_class

# 2. Numerical Data ---> we can further divide  i.e  data

# %% [markdown]
# 1. Supervised ML Models

# %%
import numpy as np
import pandas as pd

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
x = df.drop(columns = ['placed'])
y = df['placed']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

# %%
# logisticRegression ---> we will use it when we have categorical target column. it is used sigmoid
# Activation function in its backend . it is udimg probability so  its output will be in range of (0,1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# DecisionTreeClassifier

# %%
# 3 classes in target column ---> -p1Log1-p2Log2-p3Log3

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# **RandomForestClassifier**

# %%
df = pd.read_csv("/content/covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy = 'mean')

# %%
df['fever'] = si.fit_transform(df[['fever']])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df['gender'] = df['gender'].map({'Male':0, 'Female':1})

# %%
df['cough'] = df['cough'].map({'Mild':0, 'Strong':1})

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['city'] = df['city'].map({'Bangalore':0, 'Delhi':1, 'Hyderabad':2, 'Mumbai':3})

# %%
df['has_covid'] = df['has_covid'].map({'No':0, 'Yes':1})

# %%
df.head(3)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       0  103.0      0   NaN          0
# 1   27       0  100.0      0   1.0          1
# 2   42       0  101.0      0   1.0          0

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5
